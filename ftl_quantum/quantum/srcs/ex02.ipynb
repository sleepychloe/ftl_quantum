# %%
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram

# Create a quantum circuit with 1 qubit and 1 classical bit(for measure)
qc = QuantumCircuit(1, 1)

# Apply a Hadamard gate to the qubit(creates superposition)
qc.h(0)

# Measure the qubit and store the result in the classical bit
qc.measure(0, 0)

# Visualize the circuit
print(qc.draw('mpl'))

# Set up the simulator and execute
simulator = Aer.get_backend('aer_simulator')
job = simulator.run(qc, shots=500)
result = job.result()
counts = result.get_counts(qc)

total = sum(counts.values())
probabilities = {k: v/ total for k, v in counts.items()}
plot_histogram(probabilities)
# Out:
# Figure(269.064x200.667)
